# %%
# !pip install ipeadatapy 
# !pip install python-bcb

import ipeadatapy as ip
from bcb import sgs

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.3 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 31.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 1.5 MB/s eta 0:00:00eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# # mostrando teste de markdown
#
# sem ficar grandao

# %%
selic = sgs.get({'selic':432},start = '2010-01-01')

sns.set_theme()

plt.figure(figsize=(10,5))

sns.lineplot(data = selic['selic']).set(title = 'Taxa de Juros - Meta Selic definida pelo Copom %a.a.')
# Out:
# [Text(0.5, 1.0, 'Taxa de Juros - Meta Selic definida pelo Copom %a.a.')]
